# %%
import csv
import math

def generate_addition(a, b):
    code = f"def add({a}, {b}):\n    return {a} + {b}"
    equation = f"add({a}, {b}) = {a} + {b}"
    return {"code": code, "equation": equation}

def generate_linear_function(x, m, c):
    code = f"def linear_function({x}):\n    return {m} * {x} + {c}"
    equation = f"linear_function({x}) = {m} * {x} + {c}"
    return {"code": code, "equation": equation}

def generate_subtraction(a, b):
    code = f"def subtract({a}, {b}):\n    return {a} - {b}"
    equation = f"subtract({a}, {b}) = {a} - {b}"
    return {"code": code, "equation": equation}

def generate_multiplication(a, b):
    code = f"def multiply({a}, {b}):\n    return {a} * {b}"
    equation = f"multiply({a}, {b}) = {a} × {b}"
    return {"code": code, "equation": equation}

def generate_division(a, b):
    code = f"def divide({a}, {b}):\n    return {a} / {b}"
    equation = f"divide({a}, {b}) = {a} ÷ {b}"
    return {"code": code, "equation": equation}

def generate_power_function(x, n):
    code = f"def power({x}):\n    return {x} ** {n}"
    equation = f"power({x}) = {x}^{n}"
    return {"code": code, "equation": equation}

def generate_quadratic_function(x, a, b, c):
    code = f"def quadratic({x}):\n    return {a} * {x}**2 + {b} * {x} + {c}"
    equation = f"quadratic({x}) = {a}{x}² + {b}{x} + {c}"
    return {"code": code, "equation": equation}

def generate_cubic_function(x, a, b, c, d):
    code = f"def cubic({x}):\n    return {a} * {x}**3 + {b} * {x}**2 + {c} * {x} + {d}"
    equation = f"cubic({x}) = {a}{x}³ + {b}{x}² + {c}{x} + {d}"
    return {"code": code, "equation": equation}

def generate_exponential_function(x, base):
    code = f"def exponential({x}):\n    return {base} ** {x}"
    equation = f"exponential({x}) = {base}^{x}"
    return {"code": code, "equation": equation}

def generate_logarithmic_function(x, base):
    code = f"def logarithm({x}):\n    return math.log({x}, {base})"
    equation = f"logarithm({x}) = log_{base}({x})"
    return {"code": code, "equation": equation}

def generate_sine_function(x):
    code = f"def sine({x}):\n    return math.sin({x})"
    equation = f"sine({x}) = sin({x})"
    return {"code": code, "equation": equation}

def generate_cosine_function(x):
    code = f"def cosine({x}):\n    return math.cos({x})"
    equation = f"cosine({x}) = cos({x})"
    return {"code": code, "equation": equation}

def generate_tangent_function(x):
    code = f"def tangent({x}):\n    return math.tan({x})"
    equation = f"tangent({x}) = tan({x})"
    return {"code": code, "equation": equation}

def generate_factorial_function(n):
    code = f"def factorial({n}):\n    return math.factorial({n})"
    equation = f"factorial({n}) = {n}!"
    return {"code": code, "equation": equation}

def generate_absolute_value_function(x):
    code = f"def absolute_value({x}):\n    return abs({x})"
    equation = f"absolute_value({x}) = |{x}|"
    return {"code": code, "equation": equation}

def generate_modulo_operation(a, b):
    code = f"def modulo({a}, {b}):\n    return {a} % {b}"
    equation = f"modulo({a}, {b}) = {a} mod {b}"
    return {"code": code, "equation": equation}

def generate_pythagorean_theorem(a, b):
    code = f"def hypotenuse({a}, {b}):\n    return math.sqrt({a}**2 + {b}**2)"
    equation = f"hypotenuse({a}, {b}) = √({a}² + {b}²)"
    return {"code": code, "equation": equation}

def generate_relu_function(x):
    code = f"def relu({x}):\n    return max(0, {x})"
    equation = f"relu({x}) = max(0, {x})"
    return {"code": code, "equation": equation}

def generate_softmax_function(x_vector):
    code = f"def softmax({x_vector}):\n    e_x = [math.exp(i) for i in {x_vector}]\n    sum_e_x = sum(e_x)\n    return [i / sum_e_x for i in e_x]"
    equation = f"softmax({x_vector}) = exp({x_vector}) / Σ exp({x_vector})"
    return {"code": code, "equation": equation}

def generate_harmonic_mean(a, b):
    code = f"def harmonic_mean({a}, {b}):\n    return 2 / (1/{a} + 1/{b})"
    equation = f"harmonic_mean({a}, {b}) = 2 / (1/{a} + 1/{b})"
    return {"code": code, "equation": equation}

def generate_geometric_mean(a, b):
    code = f"def geometric_mean({a}, {b}):\n    return ({a} * {b}) ** 0.5"
    equation = f"geometric_mean({a}, {b}) = √({a} × {b})"
    return {"code": code, "equation": equation}

def generate_arithmetic_mean(a, b):
    code = f"def arithmetic_mean({a}, {b}):\n    return ({a} + {b}) / 2"
    equation = f"arithmetic_mean({a}, {b}) = ({a} + {b}) ÷ 2"
    return {"code": code, "equation": equation}

def generate_binomial_coefficient(n, k):
    code = f"def binomial_coefficient({n}, {k}):\n    return math.comb({n}, {k})"
    equation = f"binomial_coefficient({n}, {k}) = C({n}, {k})"
    return {"code": code, "equation": equation}
def generate_nth_root_function(x, n):
    code = f"def nth_root({x}):\n    return {x} ** (1 / {n})"
    equation = f"nth_root({x}) = {x}^(1/{n})"
    return {"code": code, "equation": equation}

def generate_log_base_function(x, base):
    code = f"def log_base({x}):\n    return math.log({x}, {base})"
    equation = f"log_base({x}) = log_{base}({x})"
    return {"code": code, "equation": equation}

def generate_hyperbolic_sine_function(x):
    code = f"def sinh({x}):\n    return math.sinh({x})"
    equation = f"sinh({x}) = sinh({x})"
    return {"code": code, "equation": equation}

def generate_hyperbolic_cosine_function(x):
    code = f"def cosh({x}):\n    return math.cosh({x})"
    equation = f"cosh({x}) = cosh({x})"
    return {"code": code, "equation": equation}

def generate_hyperbolic_tangent_function(x):
    code = f"def tanh({x}):\n    return math.tanh({x})"
    equation = f"tanh({x}) = tanh({x})"
    return {"code": code, "equation": equation}

def generate_inverse_sine_function(x):
    code = f"def arcsin({x}):\n    return math.asin({x})"
    equation = f"arcsin({x}) = sin⁻¹({x})"
    return {"code": code, "equation": equation}

def generate_inverse_cosine_function(x):
    code = f"def arccos({x}):\n    return math.acos({x})"
    equation = f"arccos({x}) = cos⁻¹({x})"
    return {"code": code, "equation": equation}

def generate_inverse_tangent_function(x):
    code = f"def arctan({x}):\n    return math.atan({x})"
    equation = f"arctan({x}) = tan⁻¹({x})"
    return {"code": code, "equation": equation}

def generate_max_function(a, b):
    code = f"def max_value({a}, {b}):\n    return max({a}, {b})"
    equation = f"max_value({a}, {b}) = max({a}, {b})"
    return {"code": code, "equation": equation}

def generate_min_function(a, b):
    code = f"def min_value({a}, {b}):\n    return min({a}, {b})"
    equation = f"min_value({a}, {b}) = min({a}, {b})"
    return {"code": code, "equation": equation}

def generate_gcd_function(a, b):
    code = f"def gcd({a}, {b}):\n    return math.gcd({a}, {b})"
    equation = f"gcd({a}, {b}) = gcd({a}, {b})"
    return {"code": code, "equation": equation}

def generate_lcm_function(a, b):
    code = f"def lcm({a}, {b}):\n    return abs({a} * {b}) // math.gcd({a}, {b})"
    equation = f"lcm({a}, {b}) = lcm({a}, {b})"
    return {"code": code, "equation": equation}

def generate_sigmoid_function(x):
    code = f"def sigmoid({x}):\n    return 1 / (1 + math.exp(-{x}))"
    equation = f"sigmoid({x}) = 1 / (1 + e^{-x})"
    return {"code": code, "equation": equation}

def generate_heaviside_step_function(x):
    code = f"def heaviside({x}):\n    return 1 if {x} >= 0 else 0"
    equation = f"heaviside({x}) = 1 if {x} ≥ 0 else 0"
    return {"code": code, "equation": equation}

def generate_euler_totient_function(n):
    code = f"def euler_totient({n}):\n"
    equation = f"euler_totient({n}) = φ({n})"
    return {"code": code, "equation": equation}

def generate_complex_conjugate(a, b):
    code = f"def complex_conjugate({a}, {b}):\n    return ({a}, -{b})"
    equation = f"complex_conjugate({a} + {b}i) = {a} - {b}i"
    return {"code": code, "equation": equation}

def generate_dot_product(a1, a2, b1, b2):
    code = f"def dot_product({a1}, {a2}, {b1}, {b2}):\n    return {a1} * {b1} + {a2} * {b2}"
    equation = f"dot_product(({a1}, {a2}), ({b1}, {b2})) = {a1}{b1} + {a2}{b2}"
    return {"code": code, "equation": equation}

def generate_cross_product(a1, a2, a3, b1, b2, b3):
    code = f"def cross_product({a1}, {a2}, {a3}, {b1}, {b2}, {b3}):\n    return ({a2}*{b3} - {a3}*{b2}, {a3}*{b1} - {a1}*{b3}, {a1}*{b2} - {a2}*{b1})"
    equation = f"cross_product(({a1}, {a2}, {a3}), ({b1}, {b2}, {b3})) = ({a2}{b3} - {a3}{b2}, {a3}{b1} - {a1}{b3}, {a1}{b2} - {a2}{b1})"
    return {"code": code, "equation": equation}

def generate_fibonacci_sequence(n):
    code = f"def fibonacci({n}):\n    a, b = 0, 1\n    for _ in range({n}):\n        a, b = b, a + b\n    return a"
    equation = f"fibonacci({n}) = F_{{{n}}}"
    return {"code": code, "equation": equation}

def generate_lucas_sequence(n):
    code = f"def lucas({n}):\n    a, b = 2, 1\n    for _ in range({n}):\n        a, b = b, a + b\n    return a"
    equation = f"lucas({n}) = L_{{{n}}}"
    return {"code": code, "equation": equation}

def generate_bessel_function(n, x):
    code = f"def bessel({n}, {x}):\n"
    equation = f"bessel({n}, {x}) = J_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_legendre_polynomial(n, x):
    code = f"def legendre({n}, {x}):\n"
    equation = f"legendre({n}, {x}) = P_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_chebyshev_polynomial(n, x):
    code = f"def chebyshev({n}, {x}):\n"
    equation = f"chebyshev({n}, {x}) = T_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_beta_function(x, y):
    code = f"def beta({x}, {y}):\n    return math.gamma({x}) * math.gamma({y}) / math.gamma({x} + {y})"
    equation = f"beta({x}, {y}) = Γ({x})Γ({y}) / Γ({x} + {y})"
    return {"code": code, "equation": equation}

def generate_gamma_function(x):
    code = f"def gamma({x}):\n    return math.gamma({x})"
    equation = f"gamma({x}) = Γ({x})"
    return {"code": code, "equation": equation}

def generate_error_function(x):
    code = f"def error_function({x}):\n"
    equation = f"error_function({x}) = erf({x})"
    return {"code": code, "equation": equation}

def generate_sigmoid_prime_function(x):
    code = f"def sigmoid_prime({x}):\n    s = sigmoid({x})\n    return s * (1 - s)"
    equation = f"sigmoid_prime({x}) = sigmoid({x})(1 - sigmoid({x}))"
    return {"code": code, "equation": equation}

def generate_softplus_function(x):
    code = f"def softplus({x}):\n    return math.log(1 + math.exp({x}))"
    equation = f"softplus({x}) = ln(1 + e^{x})"
    return {"code": code, "equation": equation}

def generate_leaky_relu_function(x, alpha):
    code = f"def leaky_relu({x}):\n    return {x} if {x} > 0 else {alpha} * {x}"
    equation = f"leaky_relu({x}) = {x} if {x} > 0 else {alpha}{x}"
    return {"code": code, "equation": equation}

# def generate_elu_function(x, alpha):
#     code = f"def elu({x}):\n    return {x} if {x} > 0 else {alpha} * (math.exp({x}) - 1)"
#     equation = f"elu({x}) = {x} if {x} > 0 else {alpha}(e^{x} - 1)"
#     return {"code": code, "equation": equation}

def generate_swish_function(x):
    code = f"def swish({x}):\n    return {x} / (1 + math.exp(-{x}))"
    equation = f"swish({x}) = {x} / (1 + e^{-x})"
    return {"code": code, "equation": equation}

def generate_inverse_function(f, y):
    code = f"def inverse_function({y}):\n"
    equation = f"inverse_function({y}) = f⁻¹({y})"
    return {"code": code, "equation": equation}

def generate_hypergeometric_function(a, b, c, z):
    code = f"def hypergeometric({a}, {b}, {c}, {z}):\n"
    equation = f"hypergeometric({a}, {b}, {c}, {z}) = ₂F₁({a}, {b}; {c}; {z})"
    return {"code": code, "equation": equation}

def generate_parabolic_function(x, a, h, k):
    code = f"def parabola({x}):\n    return {a} * ({x} - {h}) ** 2 + {k}"
    equation = f"parabola({x}) = {a}({x} - {h})² + {k}"
    return {"code": code, "equation": equation}

def generate_circle_equation(x, y, h, k, r):
    code = f"def circle_equation({x}, {y}):\n    return ({x} - {h}) ** 2 + ({y} - {k}) ** 2 - {r} ** 2"
    equation = f"circle_equation({x}, {y}) = ({x} - {h})² + ({y} - {k})² = {r}²"
    return {"code": code, "equation": equation}

def generate_ellipse_equation(x, y, h, k, a, b):
    code = f"def ellipse_equation({x}, {y}):\n    return (({x} - {h}) ** 2) / {a} ** 2 + (({y} - {k}) ** 2) / {b} ** 2 - 1"
    equation = f"ellipse_equation({x}, {y}) = (({x} - {h})² / {a}²) + (({y} - {k})² / {b}²) = 1"
    return {"code": code, "equation": equation}

def generate_hyperbola_equation(x, y, h, k, a, b):
    code = f"def hyperbola_equation({x}, {y}):\n    return (({x} - {h}) ** 2) / {a} ** 2 - (({y} - {k}) ** 2) / {b} ** 2 - 1"
    equation = f"hyperbola_equation({x}, {y}) = (({x} - {h})² / {a}²) - (({y} - {k})² / {b}²) = 1"
    return {"code": code, "equation": equation}

def generate_logistic_map_function(x, r):
    code = f"def logistic_map({x}):\n    return {r} * {x} * (1 - {x})"
    equation = f"logistic_map({x}) = {r}{x}(1 - {x})"
    return {"code": code, "equation": equation}

def generate_weierstrass_function(x):
    code = f"def weierstrass({x}):\n"
    equation = f"weierstrass({x}) = W({x})"
    return {"code": code, "equation": equation}

def generate_dirac_delta_function(x):
    code = f"def dirac_delta({x}):\n"
    equation = f"dirac_delta({x}) = δ({x})"
    return {"code": code, "equation": equation}

def generate_heaviside_function(x):
    code = f"def heaviside({x}):\n    return 0 if {x} < 0 else 1"
    equation = f"heaviside({x}) = 0 if {x} < 0 else 1"
    return {"code": code, "equation": equation}

def generate_sinc_function(x):
    code = f"def sinc({x}):\n    return 1 if {x} == 0 else math.sin({x}) / {x}"
    equation = f"sinc({x}) = sin({x}) / {x}"
    return {"code": code, "equation": equation}

def generate_ramp_function(x):
    code = f"def ramp({x}):\n    return {x} if {x} > 0 else 0"
    equation = f"ramp({x}) = {x} if {x} > 0 else 0"
    return {"code": code, "equation": equation}

def generate_unit_step_function(x):
    code = f"def unit_step({x}):\n    return 1 if {x} >= 0 else 0"
    equation = f"unit_step({x}) = 1 if {x} ≥ 0 else 0"
    return {"code": code, "equation": equation}

def generate_rectangular_function(x, width):
    code = f"def rectangular({x}):\n    return 1 if abs({x}) <= {width} / 2 else 0"
    equation = f"rectangular({x}) = 1 if |{x}| ≤ {width}/2 else 0"
    return {"code": code, "equation": equation}

def generate_triangular_function(x, width):
    code = f"def triangular({x}):\n    return max(0, ({width} / 2 - abs({x})) / ({width} / 2))"
    equation = f"triangular({x}) = max(0, 1 - 2|{x}| / {width})"
    return {"code": code, "equation": equation}

def generate_sawtooth_wave_function(x, period):
    code = f"def sawtooth_wave({x}):\n    return 2 * ({x} / {period} - math.floor({x} / {period} + 0.5))"
    equation = f"sawtooth_wave({x}) = 2({x}/{period} - floor({x}/{period} + 0.5))"
    return {"code": code, "equation": equation}

def generate_square_wave_function(x, period):
    code = f"def square_wave({x}):\n    return 1 if ({x} % {period}) < {period} / 2 else -1"
    equation = f"square_wave({x}) = 1 if {x} mod {period} < {period}/2 else -1"
    return {"code": code, "equation": equation}

def generate_kronecker_delta(i, j):
    code = f"def kronecker_delta({i}, {j}):\n    return 1 if {i} == {j} else 0"
    equation = f"kronecker_delta({i}, {j}) = δ₍{i}{j}₎"
    return {"code": code, "equation": equation}

def generate_permutation_function(n, k):
    code = f"def permutation({n}, {k}):\n    return math.perm({n}, {k})"
    equation = f"permutation({n}, {k}) = P({n}, {k})"
    return {"code": code, "equation": equation}

def generate_rising_factorial(x, n):
    code = f"def rising_factorial({x}, {n}):\n    result = 1\n    for i in range({n}):\n        result *= {x} + i\n    return result"
    equation = f"rising_factorial({x}, {n}) = ({x})^{{({n})}}"
    return {"code": code, "equation": equation}

def generate_falling_factorial(x, n):
    code = f"def falling_factorial({x}, {n}):\n    result = 1\n    for i in range({n}):\n        result *= {x} - i\n    return result"
    equation = f"falling_factorial({x}, {n}) = ({x})_{{({n})}}"
    return {"code": code, "equation": equation}

def generate_barnes_g_function(x):
    code = f"def barnes_g({x}):\n"
    equation = f"barnes_g({x}) = G({x})"
    return {"code": code, "equation": equation}

def generate_lambert_wk_function(k, x):
    code = f"def lambert_wk({k}, {x}):\n"
    equation = f"lambert_wk({k}, {x}) = W_{{{k}}}({x})"
    return {"code": code, "equation": equation}

def generate_confluent_hypergeometric_function(a, b, x):
    code = f"def confluent_hypergeometric({a}, {b}, {x}):\n    return scipy.special.hyp1f1({a}, {b}, {x})"
    equation = f"confluent_hypergeometric({a}, {b}, {x}) = M({a}, {b}, {x})"
    return {"code": code, "equation": equation}

def generate_generalized_hypergeometric_function(p, q, a_params, b_params, x):
    code = f"def generalized_hypergeometric({p}, {q}, {a_params}, {b_params}, {x}):\n"
    equation = f"generalized_hypergeometric({p}, {q}, {a_params}, {b_params}, {x}) = _{{{p}}}F_{{{q}}}({a_params}; {b_params}; {x})"
    return {"code": code, "equation": equation}

def generate_coulomb_wave_solutions(l, eta, rho):
    code = f"def coulomb_wave_solutions({l}, {eta}, {rho}):\n"
    equation = f"coulomb_wave_solutions({l}, {eta}, {rho}) = (F, G)"
    return {"code": code, "equation": equation}

def generate_parabolic_cylinder_d_function(nu, x):
    code = f"def parabolic_cylinder_d({nu}, {x}):\n    return scipy.special.pbdv({nu}, {x})[0]"
    equation = f"parabolic_cylinder_d({nu}, {x}) = D_{{{nu}}}({x})"
    return {"code": code, "equation": equation}

def generate_kelvin_ber_function(nu, x):
    code = f"def kelvin_ber({nu}, {x}):\n    return scipy.special.ber({nu}, {x})"
    equation = f"kelvin_ber({nu}, {x}) = ber_{{{nu}}}({x})"
    return {"code": code, "equation": equation}

def generate_kelvin_bei_function(nu, x):
    code = f"def kelvin_bei({nu}, {x}):\n    return scipy.special.bei({nu}, {x})"
    equation = f"kelvin_bei({nu}, {x}) = bei_{{{nu}}}({x})"
    return {"code": code, "equation": equation}

def generate_kelvin_ker_function(nu, x):
    code = f"def kelvin_ker({nu}, {x}):\n    return scipy.special.ker({nu}, {x})"
    equation = f"kelvin_ker({nu}, {x}) = ker_{{{nu}}}({x})"
    return {"code": code, "equation": equation}

def generate_kelvin_kei_function(nu, x):
    code = f"def kelvin_kei({nu}, {x}):\n    return scipy.special.kei({nu}, {x})"
    equation = f"kelvin_kei({nu}, {x}) = kei_{{{nu}}}({x})"
    return {"code": code, "equation": equation}

def generate_spherical_hankel_function_first_kind(n, x):
    code = f"def spherical_hankel1({n}, {x}):\n"
    equation = f"spherical_hankel1({n}, {x}) = h_{{{n}}}^{(1)}({x})"
    return {"code": code, "equation": equation}

def generate_spherical_hankel_function_second_kind(n, x):
    code = f"def spherical_hankel2({n}, {x}):\n"
    equation = f"spherical_hankel2({n}, {x}) = h_{{{n}}}^{(2)}({x})"
    return {"code": code, "equation": equation}

def generate_struve_function(n, x):
    code = f"def struve({n}, {x}):\n    return scipy.special.struve({n}, {x})"
    equation = f"struve({n}, {x}) = H_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_modfied_struve_function(n, x):
    code = f"def modified_struve({n}, {x}):\n    return scipy.special.modstruve({n}, {x})"
    equation = f"modified_struve({n}, {x}) = L_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_clausen_function(x):
    code = f"def clausen({x}):\n"
    equation = f"clausen({x}) = Cl_2({x})"
    return {"code": code, "equation": equation}

def generate_euler_number(n):
    code = f"def euler_number({n}):\n    return scipy.special.euler({n})"
    equation = f"euler_number({n}) = E_{{{n}}}"
    return {"code": code, "equation": equation}

def generate_bernoulli_number(n):
    code = f"def bernoulli_number({n}):\n    return scipy.special.bernoulli({n})"
    equation = f"bernoulli_number({n}) = B_{{{n}}}"
    return {"code": code, "equation": equation}

def generate_dilogarithm_spence_function(x):
    code = f"def spence({x}):\n    return scipy.special.spence({x})"
    equation = f"spence({x}) = Li₂({x})"
    return {"code": code, "equation": equation}

def generate_trigamma_function(x):
    code = f"def trigamma({x}):\n    return scipy.special.polygamma(1, {x})"
    equation = f"trigamma({x}) = ψ'({x})"
    return {"code": code, "equation": equation}

def generate_tetragamma_function(x):
    code = f"def tetragamma({x}):\n    return scipy.special.polygamma(2, {x})"
    equation = f"tetragamma({x}) = ψ''({x})"
    return {"code": code, "equation": equation}

def generate_pentagamma_function(x):
    code = f"def pentagamma({x}):\n    return scipy.special.polygamma(3, {x})"
    equation = f"pentagamma({x}) = ψ'''({x})"
    return {"code": code, "equation": equation}

def generate_laguerre_associated_polynomial(n, k, x):
    code = f"def laguerre_associated({n}, {k}, {x}):\n    return scipy.special.genlaguerre({n}, {k})({x})"
    equation = f"laguerre_associated({n}, {k}, {x}) = L_{{{n}}}^{{{k}}}({x})"
    return {"code": code, "equation": equation}

def generate_gegenbauer_polynomial(n, alpha, x):
    code = f"def gegenbauer({n}, {alpha}, {x}):\n    return scipy.special.gegenbauer({n}, {alpha})({x})"
    equation = f"gegenbauer({n}, {alpha}, {x}) = C_{{{n}}}^{{{alpha}}}({x})"
    return {"code": code, "equation": equation}

def generate_spherical_harmonic_re(n, m, theta, phi):
    code = f"def spherical_harmonic_re({n}, {m}, {theta}, {phi}):\n    return scipy.special.sph_harm({m}, {n}, {phi}, {theta}).real"
    equation = f"spherical_harmonic_re({n}, {m}, {theta}, {phi}) = Re[Y_{{{n}}}^{{{m}}}({theta}, {phi})]"
    return {"code": code, "equation": equation}

def generate_spherical_harmonic_im(n, m, theta, phi):
    code = f"def spherical_harmonic_im({n}, {m}, {theta}, {phi}):\n    return scipy.special.sph_harm({m}, {n}, {phi}, {theta}).imag"
    equation = f"spherical_harmonic_im({n}, {m}, {theta}, {phi}) = Im[Y_{{{n}}}^{{{m}}}({theta}, {phi})]"
    return {"code": code, "equation": equation}

def generate_legendre_function_q(n, x):
    code = f"def legendre_q({n}, {x}):\n"
    equation = f"legendre_q({n}, {x}) = Q_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_elliptic_pi(n, k):
    code = f"def elliptic_pi({n}, {k}):\n"
    equation = f"elliptic_pi({n}, {k}) = Π({n}, {k})"
    return {"code": code, "equation": equation}

def generate_elliptic_e_phi(phi, k):
    code = f"def elliptic_e_phi({phi}, {k}):\n"
    equation = f"elliptic_e_phi({phi}, {k}) = E({phi}, {k})"
    return {"code": code, "equation": equation}

def generate_elliptic_f(phi, k):
    code = f"def elliptic_f({phi}, {k}):\n"
    equation = f"elliptic_f({phi}, {k}) = F({phi}, {k})"
    return {"code": code, "equation": equation}

def generate_elliptic_pi_phi(n, phi, k):
    code = f"def elliptic_pi_phi({n}, {phi}, {k}):\n"
    equation = f"elliptic_pi_phi({n}, {phi}, {k}) = Π({n}; {phi}, {k})"
    return {"code": code, "equation": equation}

def generate_clausen_function(x):
    code = f"def clausen({x}):\n"
    equation = f"clausen({x}) = Cl_2({x})"
    return {"code": code, "equation": equation}

def generate_bernoulli_polynomial(n, x):
    code = f"def bernoulli_polynomial({n}, {x}):\n    return scipy.special.bernoulli({n}) * ({x} ** {n})"
    equation = f"bernoulli_polynomial({n}, {x}) = B_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_euler_polynomial(n, x):
    code = f"def euler_polynomial({n}, {x}):\n"
    equation = f"euler_polynomial({n}, {x}) = E_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_mathieu_s_function(n, q, x):
    code = f"def mathieu_s({n}, {q}, {x}):\n"
    equation = f"mathieu_s({n}, {q}, {x}) = S_{{{n}}}({q}, {x})"
    return {"code": code, "equation": equation}

def generate_mathieu_c_function(n, q, x):
    code = f"def mathieu_c({n}, {q}, {x}):\n"
    equation = f"mathieu_c({n}, {q}, {x}) = C_{{{n}}}({q}, {x})"
    return {"code": code, "equation": equation}

def generate_spherical_bessel_function_jn(n, x):
    code = f"def spherical_bessel_jn({n}, {x}):\n    return scipy.special.spherical_jn({n}, {x})"
    equation = f"spherical_bessel_jn({n}, {x}) = j_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_spherical_bessel_function_yn(n, x):
    code = f"def spherical_bessel_yn({n}, {x}):\n    return scipy.special.spherical_yn({n}, {x})"
    equation = f"spherical_bessel_yn({n}, {x}) = y_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_gegenbauer_c_polynomial(n, alpha, x):
    code = f"def gegenbauer_c({n}, {alpha}, {x}):\n    return scipy.special.gegenbauer({n}, {alpha})({x})"
    equation = f"gegenbauer_c({n}, {alpha}, {x}) = C_{{{n}}}^{{({alpha})}}({x})"
    return {"code": code, "equation": equation}

def generate_prolate_spheroidal_wave_function(m, n, c, x):
    code = f"def prolate_spheroidal({m}, {n}, {c}, {x}):\n"
    equation = f"prolate_spheroidal({m}, {n}, {c}, {x}) = Ps_{{{m},{n}}}({c}, {x})"
    return {"code": code, "equation": equation}

def generate_oblate_spheroidal_wave_function(m, n, c, x):
    code = f"def oblate_spheroidal({m}, {n}, {c}, {x}):\n"
    equation = f"oblate_spheroidal({m}, {n}, {c}, {x}) = Os_{{{m},{n}}}({c}, {x})"
    return {"code": code, "equation": equation}

def generate_jacobi_theta_function(n, z, q):
    code = f"def jacobi_theta({n}, {z}, {q}):\n"
    equation = f"jacobi_theta({n}, {z}, {q}) = θ_{{{n}}}({z}, {q})"
    return {"code": code, "equation": equation}

def generate_lambert_transform(f, s):
    code = f"def lambert_transform({f}, {s}):\n"
    equation = f"lambert_transform({s}) = L[ {f} ]({s})"
    return {"code": code, "equation": equation}

def generate_mellin_transform(f, s):
    code = f"def mellin_transform({f}, {s}):\n"
    equation = f"mellin_transform({s}) = M[ {f} ]({s})"
    return {"code": code, "equation": equation}

def generate_wright_function(a, b, z):
    code = f"def wright({a}, {b}, {z}):\n"
    equation = f"wright({a}, {b}, {z}) = Φ({a}, {b}; {z})"
    return {"code": code, "equation": equation}

def generate_fox_h_function(parameters, z):
    code = f"def fox_h({parameters}, {z}):\n"
    equation = f"fox_h({parameters}, {z}) = H({parameters}; {z})"
    return {"code": code, "equation": equation}

def generate_meijer_g_function(parameters, z):
    code = f"def meijer_g({parameters}, {z}):\n    return scipy.special.meijerg({parameters}, {z})"
    equation = f"meijer_g({parameters}, {z}) = G({parameters}; {z})"
    return {"code": code, "equation": equation}

def generate_rademacher_function(n, q):
    code = f"def rademacher({n}, {q}):\n"
    equation = f"rademacher({n}, {q}) = R({n}, {q})"
    return {"code": code, "equation": equation}

def generate_wigner_d_function(j, m, mp, beta):
    code = f"def wigner_d({j}, {m}, {mp}, {beta}):\n"
    equation = f"wigner_d({j}, {m}, {mp}, {beta}) = d^{{{j}}}_{{{m}{mp}}}({beta})"
    return {"code": code, "equation": equation}

def generate_krawtchouk_polynomial(n, p, N, x):
    code = f"def krawtchouk({n}, {p}, {N}, {x}):\n"
    equation = f"krawtchouk({n}, {p}, {N}, {x}) = K_{{{n}}}({x}; {p}, {N})"
    return {"code": code, "equation": equation}

def generate_ultraspherical_polynomial(n, lambda_, x):
    code = f"def ultraspherical({n}, {lambda_}, {x}):\n"
    equation = f"ultraspherical({n}, {lambda_}, {x}) = C_{{{n}}}^{{{lambda_}}}({x})"
    return {"code": code, "equation": equation}

def generate_bateman_function(k, x):
    code = f"def bateman({k}, {x}):\n"
    equation = f"bateman({k}, {x}) = B_{{{k}}}({x})"
    return {"code": code, "equation": equation}

def generate_bessel_clifford_function(n, x):
    code = f"def bessel_clifford({n}, {x}):\n"
    equation = f"bessel_clifford({n}, {x}) = C_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_modular_lambda_function(tau):
    code = f"def modular_lambda({tau}):\n"
    equation = f"modular_lambda({tau}) = λ({tau})"
    return {"code": code, "equation": equation}

def generate_sievers_function(n, x):
    code = f"def sievers({n}, {x}):\n"
    equation = f"sievers({n}, {x}) = S_{{{n}}}({x})"
    return {"code": code, "equation": equation}

def generate_erf_inverse_function(x):
    code = f"def erf_inv({x}):\n    return scipy.special.erfinv({x})"
    equation = f"erf_inv({x}) = erf⁻¹({x})"
    return {"code": code, "equation": equation}

def generate_besselj_zero(n, k):
    code = f"def besselj_zero({n}, {k}):\n    return scipy.special.jn_zeros({n}, {k})[{k}-1]"
    equation = f"besselj_zero({n}, {k}) = j_{{{n},{k}}}"
    return {"code": code, "equation": equation}

def generate_zeta_zero(n):
    code = f"def zeta_zero({n}):\n"
    equation = f"zeta_zero({n}) = ρ_{{{n}}}"
    return {"code": code, "equation": equation}

dataset = []
dataset.append(generate_addition("a", "b"))
dataset.append(generate_linear_function("x", "a", "b"))
dataset.append(generate_addition("a", "b"))
dataset.append(generate_linear_function("x", "m", "c"))
dataset.append(generate_subtraction("x", "y"))
dataset.append(generate_multiplication("u", "v"))
dataset.append(generate_division("numerator", "denominator"))
dataset.append(generate_power_function("x", "n"))
dataset.append(generate_quadratic_function("x", "a", "b", "c"))
dataset.append(generate_cubic_function("x", "a", "b", "c", "d"))
dataset.append(generate_exponential_function("x", "e"))
dataset.append(generate_logarithmic_function("x", "b"))
dataset.append(generate_sine_function("theta"))
dataset.append(generate_cosine_function("theta"))
dataset.append(generate_tangent_function("theta"))
dataset.append(generate_factorial_function("n"))
dataset.append(generate_absolute_value_function("x"))
dataset.append(generate_modulo_operation("x", "y"))
dataset.append(generate_pythagorean_theorem("a", "b"))
dataset.append(generate_relu_function("x"))
dataset.append(generate_harmonic_mean("a", "b"))
dataset.append(generate_geometric_mean("a", "b"))
dataset.append(generate_arithmetic_mean("a", "b"))
dataset.append(generate_binomial_coefficient("n", "k"))
dataset.append(generate_nth_root_function("x", "n"))
dataset.append(generate_log_base_function("x", "b"))
dataset.append(generate_hyperbolic_sine_function("x"))
dataset.append(generate_hyperbolic_cosine_function("x"))
dataset.append(generate_hyperbolic_tangent_function("x"))
dataset.append(generate_inverse_sine_function("x"))
dataset.append(generate_inverse_cosine_function("x"))
dataset.append(generate_inverse_tangent_function("x"))
dataset.append(generate_max_function("a", "b"))
dataset.append(generate_min_function("a", "b"))
dataset.append(generate_gcd_function("a", "b"))
dataset.append(generate_lcm_function("a", "b"))
#dataset.append(generate_sigmoid_function("x"))
dataset.append(generate_heaviside_step_function("x"))
dataset.append(generate_euler_totient_function("n"))
dataset.append(generate_complex_conjugate("a", "b"))
dataset.append(generate_dot_product("a1", "a2", "b1", "b2"))
dataset.append(generate_cross_product("a1", "a2", "a3", "b1", "b2", "b3"))
dataset.append(generate_fibonacci_sequence("n"))
dataset.append(generate_lucas_sequence("n"))
dataset.append(generate_bessel_function("n", "x"))
dataset.append(generate_legendre_polynomial("n", "x"))
dataset.append(generate_chebyshev_polynomial("n", "x"))
dataset.append(generate_beta_function("x", "y"))
dataset.append(generate_gamma_function("x"))
dataset.append(generate_error_function("x"))
dataset.append(generate_sigmoid_prime_function("x"))
dataset.append(generate_softplus_function("x"))
dataset.append(generate_leaky_relu_function("x", "alpha"))
#dataset.append(generate_elu_function("x", "alpha"))
#dataset.append(generate_swish_function("x"))
dataset.append(generate_inverse_function("f", "y"))
dataset.append(generate_hypergeometric_function("a", "b", "c", "z"))
dataset.append(generate_parabolic_function("x", "a", "h", "k"))
dataset.append(generate_circle_equation("x", "y", "h", "k", "r"))
dataset.append(generate_ellipse_equation("x", "y", "h", "k", "a", "b"))
dataset.append(generate_hyperbola_equation("x", "y", "h", "k", "a", "b"))
dataset.append(generate_logistic_map_function("x", "r"))
dataset.append(generate_weierstrass_function("x"))
dataset.append(generate_dirac_delta_function("x"))
dataset.append(generate_heaviside_function("x"))
dataset.append(generate_sinc_function("x"))
dataset.append(generate_ramp_function("x"))
dataset.append(generate_unit_step_function("x"))
dataset.append(generate_rectangular_function("x", "width"))
dataset.append(generate_triangular_function("x", "width"))
dataset.append(generate_sawtooth_wave_function("x", "period"))
dataset.append(generate_square_wave_function("x", "period"))
dataset.append(generate_kronecker_delta("i", "j"))
dataset.append(generate_permutation_function("n", "k"))
dataset.append(generate_rising_factorial("x", "n"))
dataset.append(generate_falling_factorial("x", "n"))

# Write to CSV
with open('dataset.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=["code", "equation"])
    writer.writeheader()
    for entry in dataset:
        writer.writerow({"code": entry["code"], "equation": entry["equation"]})
